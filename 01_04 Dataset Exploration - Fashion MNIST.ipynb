# %%
# !pip install torchvision
# Out:
# Collecting torchvision
#   Using cached torchvision-0.17.1-cp39-cp39-win_amd64.whl (1.2 MB)
# Requirement already satisfied: numpy in c:\users\gupta\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\gupta\anaconda3\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: torch==2.2.1 in c:\users\gupta\anaconda3\lib\site-packages (from torchvision) (2.2.1)
# Requirement already satisfied: filelock in c:\users\gupta\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (3.3.1)
# Requirement already satisfied: jinja2 in c:\users\gupta\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (2.11.3)
# Requirement already satisfied: fsspec in c:\users\gupta\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (2024.2.0)
# Requirement already satisfied: sympy in c:\users\gupta\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (1.9)
# Requirement already satisfied: networkx in c:\users\gupta\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\gupta\anaconda3\lib\site-packages (from torch==2.2.1->torchvision) (4.9.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gupta\anaconda3\lib\site-packages (from jinja2->torch==2.2.1->torchvision) (1.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gupta\anaconda3\lib\site-packages (from sympy->torch==2.2.1->torchvision) (1.2.1)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.17.1
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gupta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gupta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gupta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gupta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gupta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gupta\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gupta\anaconda3\lib\site-packages)

# %%
# import needed libraries
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import numpy as np

# %%
# create training dataset
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

# %%
# create testing dataset 
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %%
# create a validate sample from the training dataset
indices = list(range(len(training_data)))
np.random.shuffle(indices)
split = int(np.floor(0.2 * len(training_data)))
train_sample = SubsetRandomSampler(indices[:split])
validate_sample = SubsetRandomSampler(indices[split:])

# %%
# data loader
trainloader = torch.utils.data.DataLoader(training_data, sampler=train_sample, batch_size=64)
validloader = torch.utils.data.DataLoader(training_data, sampler=validate_sample, batch_size=64)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle = True)

# %%
# create a data iterator
# %matplotlib inline
dataiter = iter(trainloader)
print(dataiter)
images,labels = dataiter.__next__()
# Out:
# <torch.utils.data.dataloader._SingleProcessDataLoaderIter object at 0x00000163A70DB400>

# %%
# plot the data
fig = plt.figure(figsize=(15,5))
for i in np.arange(20):
    ax = fig.add_subplot(4, int(20/4), i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[i]), cmap='gray')
    ax.set_title(labels[i].item())
    fig.tight_layout()
